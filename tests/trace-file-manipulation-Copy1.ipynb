# %%
## TESTS START FROM LINE 1504 (tomohara-aliases.bash)

## Bracketed Paste is disabled to prevent characters after output
## Example: 
# $ echo 'Hi'
# | Hi?2004l

bind "set enable-bracketed-paste off"

# %%
## TEST:  Make sure simple prompt used (e.g., no escapes that might contaminate output)
## PS1="$ "
## TODO: PS1="> " 

## NOTE: The Jupyter bash kernel requires that PS1 not be modified as they customize it. 
echo $PS1
# Out:
# [PEXP\[\]ECT_PROMPT>

# %%
# Delete all aliases and function
# TODO: Instead start from pristine environment
unalias -a
alias | wc -l
for f in $(typeset -f | egrep '^\w+'); do unset -f $f; done
typeset -f | egrep '^\w+' | wc -l
# Out:
# 0
# 0

# %%
alias testuser="sed -r "s/"$USER"+/user/g""
alias testnum="sed -r "s/[0-9]/X/g""

# %%
# Setting a temp directory for tests
TMP=/tmp/test-file-manipulation

## NOTE: Source it directly from the ./tests directory.
BIN_DIR=$PWD/..

alias | wc -l
# Out:
# 2

# %%
## NOTE: For reproducability, the directory name needs to be fixed
## In place of $$, use a psuedo random number (e,g., 9890)
## *** All output from one run to the next needs to be the same ***

## temp_dir=$TMP/test-$$
temp_dir=$TMP/test-9890

mkdir -p "$temp_dir"
# TODO: /bin/rm -rvf "$temp_dir"
cd "$temp_dir"
pwd

#ALIAS FOR PRINTING SEPERATION LINES (FOR JUPYTER)
alias linebr="printf '%*s\n' "${COLUMNS:-$(tput cols)}" '' | tr ' ' -"
# Out:
# /tmp/test-file-manipulation/test-9890

# %%
# Count aliases proper
alias | wc -l
# Count functions
typeset -f | egrep '^\w+' | wc -l
# Out:
# 3
# 0

# %%
source do_setup.bash
# Out:
# cond-setenv: command not found
# cond-setenv: command not found
# cond-setenv: command not found
# cond-setenv: command not found
# cond-setenv: command not found
# cond-setenv: command not found
# cond-setenv: command not found

# %%
rm -rf ./*
free -m > freemem_mb.txt

asc-it freemem_mb.txt 
#(NEED SOLUTION FOR bash: BACKUP/freemem_mb.txt: No such file or directory)
#(IN CASE OF 'BACKUP'->'backup' IN asc-it, ERROR = bash: asc: command not found)
linebr

ls -l ./backup/ | testuser | testnum | awk '!($6="")'
linebr

cat ./backup/freemem_mb.txt | testnum
# Out:
# removed './adhoc-tests.test'
# removed './alias-calculator-commands-EXTERNALSOURCING.ipynb'
# removed './alias-calculator-commands.ipynb'
# removed './alias-cd-commands.ipynb'
# removed './alias-grep-commands.ipynb'
# removed './alias-trace-misc-commands.ipynb'
# removed './auto_batspp_mezcla.py'
# removed './auto_batspp.py'
# removed './bats-only/trace-unix-general.bats'
# removed './bats-only/json-related-alias.bats'
# removed './bats-only/testbook-test-dir-aliases.bats'
# removed './bats-only/trace-file-manipulation.bats'
# removed './bats-only/tomasohara-aliases-test.bats'
# removed './bats-only/alias-cd-commands.bats'
# removed './bats-only/trace-unix-alias.bats'
# removed './bats-only/test-dir-alias.bats'
# removed './bats-only/more-tomohara-aliases-test.bats'
# removed './bats-only/trace-python-commands.bats'
# removed './bats-only/alias-calculator-commands.bats'
# removed './bats-only/trace-linux-admin-alias.bats'
# removed './bats-only/test-cond-env-setting.bats'
# removed './bats-only/test-check-errors.bats'
# removed './bats-only/dir-aliases-test-revised.bats'
# removed './bats-only/trace-setup-sorting-wrappers.bats'
# removed './bats-only/calc-entropy-tests.bats'
# removed './bats-only/alias-trace-misc-commands.bats'
# removed './bats-only/hello-world-basic.bats'
# removed './bats-only/command-override-cp-mv.bats'
# removed './bats-only/alias-grep-commands.bats'
# removed './bats-only/trace-line-words-commands.bats'
# removed './bats-only/trace-extensionless-shortcut-unicode.bats'
# removed './bats-only/hello-world-revised.bats'
# removed './bats-only/trace-extensionless-shortcut-V2.bats'
# removed directory './bats-only'
# removed './batspp-only/trace-file-manipulation.batspp'
# removed './batspp-only/testbook-test-dir-aliases.batspp'
# removed './batspp-only/test-cond-env-setting.batspp'
# removed './batspp-only/trace-setup-sorting-wrappers.batspp'
# removed './batspp-only/hello-world-basic.batspp'
# removed './batspp-only/trace-line-words-commands.batspp'
# removed './batspp-only/alias-calculator-commands.batspp'
# removed './batspp-only/alias-cd-commands.batspp'
# removed './batspp-only/alias-trace-misc-commands.batspp'
# removed './batspp-only/trace-unix-general.batspp'
# removed './batspp-only/dir-aliases-test-revised.batspp'
# removed './batspp-only/hello-world-revised.batspp'
# removed './batspp-only/trace-python-commands.batspp'
# removed './batspp-only/trace-extensionless-shortcut-V2.batspp'
# removed './batspp-only/trace-extensionless-shortcut-unicode.batspp'
# removed './batspp-only/more-tomohara-aliases-test.batspp'
# removed './batspp-only/trace-unix-alias.batspp'
# removed './batspp-only/test-check-errors.batspp'
# removed './batspp-only/alias-grep-commands.batspp'
# removed './batspp-only/calc-entropy-tests.batspp'
# removed './batspp-only/json-related-alias.batspp'
# removed './batspp-only/command-override-cp-mv.batspp'
# removed './batspp-only/tomasohara-aliases-test.batspp'
# removed './batspp-only/trace-linux-admin-alias.batspp'
# removed './batspp-only/test-dir-alias.batspp'
# removed directory './batspp-only'
# removed './batspp_report_kcov.py'
# removed './batspp-report-output.txt'
# removed './batspp_report.py'
# removed './calc_entropy.input'
# removed './calc_entropy.input2'
# removed './calc_entropy.simple.input'
# removed './calc_entropy.simple.input2'
# removed './calc-entropy-tests.ipynb'
# removed './command-override-cp-mv.ipynb'
# removed './_dir-aliases.bash'
# removed './dir-aliases-test-revised.ipynb'
# removed './docshtest.rst'
# removed './hello-world-basic.ipynb'
# removed './hello-world-revised.ipynb'
# removed './immediate-reports/TRACE_MISC_COMMANDS.txt'
# removed './immediate-reports/CHECK_EXTENSIONLESS_COMMANDS.txt'
# removed './immediate-reports/JSON_COMMANDS.txt'
# removed './immediate-reports/UNIXALIAS.txt'
# removed './immediate-reports/HWB_COMMANDS.txt'
# removed './immediate-reports/HWR_COMMANDS.txt'
# removed './immediate-reports/CHECK_DIR_COMMANDS.txt'
# removed './immediate-reports/TES.txt'
# removed './immediate-reports/MISC_LOCENV_COMMANDS.txt'
# removed './immediate-reports/CHECK_LINUXADMIN_COMMANDS.txt'
# removed './immediate-reports/CHECK_DIR_TESTBOOK_COMMANDS.txt'
# removed './immediate-reports/.TES.txt.swp'
# removed './immediate-reports/TRACE_MISC_CP1.txt'
# removed './immediate-reports/CHECK_UNIXGENERAL_COMMANDS.txt'
# removed './immediate-reports/MORE_TOM_COMMANDS.txt'
# removed './immediate-reports/CHECK_FILE_MPN_COMMANDS.txt'
# removed './immediate-reports/DIR_REVISE_COMMANDS.txt'
# removed './immediate-reports/TPS.txt'
# removed './immediate-reports/ENTROPY_COMMANDS.txt'
# removed './immediate-reports/CHECK_CONDENV_COMMANDS.txt'
# removed './immediate-reports/CP_MV_ORI_COMMANDS.txt'
# removed './immediate-reports/temp-reports/CHECKERRORS.TXT'
# removed './immediate-reports/temp-reports/OVERRIDETEMP1.TXT'
# removed './immediate-reports/temp-reports/DIRALIASTEMP.TXT'
# removed './immediate-reports/temp-reports/TESTDIR.TXT'
# removed './immediate-reports/temp-reports/EXTENSIONLESS.TXT'
# removed './immediate-reports/temp-reports/CONDTEST.TXT'
# removed './immediate-reports/temp-reports/PYTHON.TXT'
# removed './immediate-reports/temp-reports/UNIXALIAS.TXT'
# removed './immediate-reports/temp-reports/TESTBOOK.TXT'
# removed directory './immediate-reports/temp-reports'
# removed './immediate-reports/CHECK_TOMASOHARA_COMMANDS.txt'
# removed './immediate-reports/ATMCC1.txt'
# removed './immediate-reports/CHECK_LINEWORD_COMMANDS.txt'
# removed './immediate-reports/COPY1.TXT'
# removed './immediate-reports/CHECK_PY_COMMANDS.txt'
# removed './immediate-reports/CHECK_UNIXALIAS__COMMANDS.txt'
# removed './immediate-reports/TRACE_MISC_CP.txt'
# removed './immediate-reports/CHECK_ERROR_COMMANDS.txt'
# removed directory './immediate-reports'
# removed './json-related-alias.ipynb'
# removed './jupyter_to_batspp.py'
# removed './kcov-output/dir-aliases-test-revised/glass.png'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/glass.png'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/cov.xml'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/0ad8a9e6'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/968a9270'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata/8828c6ed'
# removed directory './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/metadata'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/coverage.db'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bcov.css'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats.25502.src.968a9270.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/index.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/glass.png'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/data'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats.25502.src.968a9270.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/coverage.json'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/index.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/summary.db'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/codecov.json'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/amber.png'
# removed './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './kcov-output/dir-aliases-test-revised/bats.e38fe61c8733e2cd'
# removed './kcov-output/dir-aliases-test-revised/bash-helper.sh'
# removed './kcov-output/dir-aliases-test-revised/bcov.css'
# removed './kcov-output/dir-aliases-test-revised/index.html'
# removed './kcov-output/dir-aliases-test-revised/data/glass.png'
# removed './kcov-output/dir-aliases-test-revised/data/tablesorter-theme.css'
# removed './kcov-output/dir-aliases-test-revised/data/bcov.css'
# removed './kcov-output/dir-aliases-test-revised/data/js/kcov.js'
# removed './kcov-output/dir-aliases-test-revised/data/js/handlebars.js'
# removed './kcov-output/dir-aliases-test-revised/data/js/jquery.min.js'
# removed './kcov-output/dir-aliases-test-revised/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/dir-aliases-test-revised/data/js/tablesorter.min.js'
# removed directory './kcov-output/dir-aliases-test-revised/data/js'
# removed './kcov-output/dir-aliases-test-revised/data/amber.png'
# removed directory './kcov-output/dir-aliases-test-revised/data'
# removed './kcov-output/dir-aliases-test-revised/bats'
# removed './kcov-output/dir-aliases-test-revised/libbash_execve_redirector.so'
# removed './kcov-output/dir-aliases-test-revised/index.js'
# removed './kcov-output/dir-aliases-test-revised/bash-helper-debug-trap.sh'
# removed './kcov-output/dir-aliases-test-revised/libbash_tracefd_cloexec.so'
# removed './kcov-output/dir-aliases-test-revised/amber.png'
# removed directory './kcov-output/dir-aliases-test-revised'
# removed './kcov-output/calc-entropy-tests/glass.png'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/glass.png'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats.31436.src.746e3011.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/cov.xml'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/0ad8a9e6'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/746e3011'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed directory './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/metadata'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/coverage.db'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bcov.css'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/index.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/glass.png'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/data'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/coverage.json'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/index.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/summary.db'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats.31436.src.746e3011.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/codecov.json'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/amber.png'
# removed './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './kcov-output/calc-entropy-tests/bats.e38fe61c8733e2cd'
# removed './kcov-output/calc-entropy-tests/bash-helper.sh'
# removed './kcov-output/calc-entropy-tests/bcov.css'
# removed './kcov-output/calc-entropy-tests/index.html'
# removed './kcov-output/calc-entropy-tests/data/glass.png'
# removed './kcov-output/calc-entropy-tests/data/tablesorter-theme.css'
# removed './kcov-output/calc-entropy-tests/data/bcov.css'
# removed './kcov-output/calc-entropy-tests/data/js/kcov.js'
# removed './kcov-output/calc-entropy-tests/data/js/handlebars.js'
# removed './kcov-output/calc-entropy-tests/data/js/jquery.min.js'
# removed './kcov-output/calc-entropy-tests/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/calc-entropy-tests/data/js/tablesorter.min.js'
# removed directory './kcov-output/calc-entropy-tests/data/js'
# removed './kcov-output/calc-entropy-tests/data/amber.png'
# removed directory './kcov-output/calc-entropy-tests/data'
# removed './kcov-output/calc-entropy-tests/bats'
# removed './kcov-output/calc-entropy-tests/libbash_execve_redirector.so'
# removed './kcov-output/calc-entropy-tests/index.js'
# removed './kcov-output/calc-entropy-tests/bash-helper-debug-trap.sh'
# removed './kcov-output/calc-entropy-tests/libbash_tracefd_cloexec.so'
# removed './kcov-output/calc-entropy-tests/amber.png'
# removed directory './kcov-output/calc-entropy-tests'
# removed './kcov-output/trace-unix-general/glass.png'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/glass.png'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats.24816.src.9397e942.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/cov.xml'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/0ad8a9e6'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/9397e942'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed directory './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/metadata'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/coverage.db'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bcov.css'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/index.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats.24816.src.9397e942.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/glass.png'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/data'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/coverage.json'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/index.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/summary.db'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/codecov.json'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/amber.png'
# removed './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './kcov-output/trace-unix-general/bats.e38fe61c8733e2cd'
# removed './kcov-output/trace-unix-general/bash-helper.sh'
# removed './kcov-output/trace-unix-general/bcov.css'
# removed './kcov-output/trace-unix-general/index.html'
# removed './kcov-output/trace-unix-general/data/glass.png'
# removed './kcov-output/trace-unix-general/data/tablesorter-theme.css'
# removed './kcov-output/trace-unix-general/data/bcov.css'
# removed './kcov-output/trace-unix-general/data/js/kcov.js'
# removed './kcov-output/trace-unix-general/data/js/handlebars.js'
# removed './kcov-output/trace-unix-general/data/js/jquery.min.js'
# removed './kcov-output/trace-unix-general/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/trace-unix-general/data/js/tablesorter.min.js'
# removed directory './kcov-output/trace-unix-general/data/js'
# removed './kcov-output/trace-unix-general/data/amber.png'
# removed directory './kcov-output/trace-unix-general/data'
# removed './kcov-output/trace-unix-general/bats'
# removed './kcov-output/trace-unix-general/libbash_execve_redirector.so'
# removed './kcov-output/trace-unix-general/index.js'
# removed './kcov-output/trace-unix-general/bash-helper-debug-trap.sh'
# removed './kcov-output/trace-unix-general/libbash_tracefd_cloexec.so'
# removed './kcov-output/trace-unix-general/amber.png'
# removed directory './kcov-output/trace-unix-general'
# removed './kcov-output/alias-grep-commands/glass.png'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/glass.png'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/cov.xml'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/0ad8a9e6'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/e1420193'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata/8828c6ed'
# removed directory './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/metadata'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/coverage.db'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bcov.css'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats.30978.src.e1420193.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/index.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/glass.png'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/data'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/coverage.json'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/index.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/summary.db'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/codecov.json'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats.30978.src.e1420193.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/amber.png'
# removed './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './kcov-output/alias-grep-commands/bats.e38fe61c8733e2cd'
# removed './kcov-output/alias-grep-commands/bash-helper.sh'
# removed './kcov-output/alias-grep-commands/bcov.css'
# removed './kcov-output/alias-grep-commands/index.html'
# removed './kcov-output/alias-grep-commands/data/glass.png'
# removed './kcov-output/alias-grep-commands/data/tablesorter-theme.css'
# removed './kcov-output/alias-grep-commands/data/bcov.css'
# removed './kcov-output/alias-grep-commands/data/js/kcov.js'
# removed './kcov-output/alias-grep-commands/data/js/handlebars.js'
# removed './kcov-output/alias-grep-commands/data/js/jquery.min.js'
# removed './kcov-output/alias-grep-commands/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/alias-grep-commands/data/js/tablesorter.min.js'
# removed directory './kcov-output/alias-grep-commands/data/js'
# removed './kcov-output/alias-grep-commands/data/amber.png'
# removed directory './kcov-output/alias-grep-commands/data'
# removed './kcov-output/alias-grep-commands/bats'
# removed './kcov-output/alias-grep-commands/libbash_execve_redirector.so'
# removed './kcov-output/alias-grep-commands/index.js'
# removed './kcov-output/alias-grep-commands/bash-helper-debug-trap.sh'
# removed './kcov-output/alias-grep-commands/libbash_tracefd_cloexec.so'
# removed './kcov-output/alias-grep-commands/amber.png'
# removed directory './kcov-output/alias-grep-commands'
# removed './kcov-output/more-tomohara-aliases-test/glass.png'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/glass.png'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/cov.xml'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/0ad8a9e6'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/4ed27958'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed directory './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/metadata'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/coverage.db'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats.29113.src.4ed27958.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bcov.css'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/index.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/glass.png'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/data'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats.29113.src.4ed27958.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/coverage.json'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/index.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/summary.db'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/codecov.json'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/amber.png'
# removed './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './kcov-output/more-tomohara-aliases-test/bats.e38fe61c8733e2cd'
# removed './kcov-output/more-tomohara-aliases-test/bash-helper.sh'
# removed './kcov-output/more-tomohara-aliases-test/bcov.css'
# removed './kcov-output/more-tomohara-aliases-test/index.html'
# removed './kcov-output/more-tomohara-aliases-test/data/glass.png'
# removed './kcov-output/more-tomohara-aliases-test/data/tablesorter-theme.css'
# removed './kcov-output/more-tomohara-aliases-test/data/bcov.css'
# removed './kcov-output/more-tomohara-aliases-test/data/js/kcov.js'
# removed './kcov-output/more-tomohara-aliases-test/data/js/handlebars.js'
# removed './kcov-output/more-tomohara-aliases-test/data/js/jquery.min.js'
# removed './kcov-output/more-tomohara-aliases-test/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/more-tomohara-aliases-test/data/js/tablesorter.min.js'
# removed directory './kcov-output/more-tomohara-aliases-test/data/js'
# removed './kcov-output/more-tomohara-aliases-test/data/amber.png'
# removed directory './kcov-output/more-tomohara-aliases-test/data'
# removed './kcov-output/more-tomohara-aliases-test/bats'
# removed './kcov-output/more-tomohara-aliases-test/libbash_execve_redirector.so'
# removed './kcov-output/more-tomohara-aliases-test/index.js'
# removed './kcov-output/more-tomohara-aliases-test/bash-helper-debug-trap.sh'
# removed './kcov-output/more-tomohara-aliases-test/libbash_tracefd_cloexec.so'
# removed './kcov-output/more-tomohara-aliases-test/amber.png'
# removed directory './kcov-output/more-tomohara-aliases-test'
# removed './kcov-output/trace-extensionless-shortcut-V2/glass.png'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/glass.png'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats.27971.src.df78e996.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/cov.xml'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats-exec-test.ad8a9e6.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/0ad8a9e6'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/df78e996'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed directory './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/metadata'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/coverage.db'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bcov.css'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/index.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/glass.png'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/data'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats.27971.src.df78e996.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/coverage.json'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './kcov-output/trace-extensionless-shortcut-V2/bats.e38fe61c8733e2cd/index.js'
# ...
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './temp/ATM/bats.e38fe61c8733e2cd/data/js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './temp/ATM/bats.e38fe61c8733e2cd/data'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats.19763.src.2fd54d08.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/coverage.json'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './temp/ATM/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/index.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/summary.db'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/codecov.json'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './temp/ATM/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './temp/ATM/bats.e38fe61c8733e2cd/amber.png'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats.19763.src.2fd54d08.html'
# removed './temp/ATM/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './temp/ATM/bats.e38fe61c8733e2cd'
# removed './temp/ATM/bash-helper.sh'
# removed './temp/ATM/bcov.css'
# removed './temp/ATM/index.html'
# removed './temp/ATM/data/glass.png'
# removed './temp/ATM/data/tablesorter-theme.css'
# removed './temp/ATM/data/bcov.css'
# removed './temp/ATM/data/js/kcov.js'
# removed './temp/ATM/data/js/handlebars.js'
# removed './temp/ATM/data/js/jquery.min.js'
# removed './temp/ATM/data/js/jquery.tablesorter.widgets.min.js'
# removed './temp/ATM/data/js/tablesorter.min.js'
# removed directory './temp/ATM/data/js'
# removed './temp/ATM/data/amber.png'
# removed directory './temp/ATM/data'
# removed './temp/ATM/bats'
# removed './temp/ATM/libbash_execve_redirector.so'
# removed './temp/ATM/index.js'
# removed './temp/ATM/bash-helper-debug-trap.sh'
# removed './temp/ATM/libbash_tracefd_cloexec.so'
# removed './temp/ATM/amber.png'
# removed directory './temp/ATM'
# removed './temp/tpc.batspp'
# removed './temp/ATMsimp/glass.png'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/glass.png'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats.20500.src.215d9c65.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/cov.xml'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/215d9c65'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed directory './temp/ATMsimp/bats.e38fe61c8733e2cd/metadata'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/coverage.db'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats.20500.src.215d9c65.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bcov.css'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/index.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/glass.png'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './temp/ATMsimp/bats.e38fe61c8733e2cd/data/js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './temp/ATMsimp/bats.e38fe61c8733e2cd/data'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/coverage.json'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/index.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/summary.db'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/codecov.json'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/amber.png'
# removed './temp/ATMsimp/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './temp/ATMsimp/bats.e38fe61c8733e2cd'
# removed './temp/ATMsimp/bash-helper.sh'
# removed './temp/ATMsimp/bcov.css'
# removed './temp/ATMsimp/index.html'
# removed './temp/ATMsimp/data/glass.png'
# removed './temp/ATMsimp/data/tablesorter-theme.css'
# removed './temp/ATMsimp/data/bcov.css'
# removed './temp/ATMsimp/data/js/kcov.js'
# removed './temp/ATMsimp/data/js/handlebars.js'
# removed './temp/ATMsimp/data/js/jquery.min.js'
# removed './temp/ATMsimp/data/js/jquery.tablesorter.widgets.min.js'
# removed './temp/ATMsimp/data/js/tablesorter.min.js'
# removed directory './temp/ATMsimp/data/js'
# removed './temp/ATMsimp/data/amber.png'
# removed directory './temp/ATMsimp/data'
# removed './temp/ATMsimp/bats'
# removed './temp/ATMsimp/libbash_execve_redirector.so'
# removed './temp/ATMsimp/index.js'
# removed './temp/ATMsimp/bash-helper-debug-trap.sh'
# removed './temp/ATMsimp/libbash_tracefd_cloexec.so'
# removed './temp/ATMsimp/amber.png'
# removed directory './temp/ATMsimp'
# removed './temp/autobatsppmain.txt'
# removed './temp/tpc/glass.png'
# removed './temp/tpc/bats.e38fe61c8733e2cd/glass.png'
# removed './temp/tpc/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.32713.src.9c4f9e50.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/common.bash.7a8bdafa.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.32455.src.430f5cb5.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/warnings.bash.92955179.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.51601793.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/cov.xml'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/c89b1ce6'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/6dd62e59'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/9c4f9e50'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/7a8bdafa'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/d47fd49d'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/b5ee664b'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/92955179'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/430f5cb5'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/c477ed39'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/d35e7a84'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/51601793'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/55314897'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/5e38e1fa'
# removed './temp/tpc/bats.e38fe61c8733e2cd/metadata/e2c749da'
# removed directory './temp/tpc/bats.e38fe61c8733e2cd/metadata'
# removed './temp/tpc/bats.e38fe61c8733e2cd/warnings.bash.92955179.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/coverage.db'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-exec-file.5e38e1fa.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.32713.src.9c4f9e50.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/sonarqube.xml'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bcov.css'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.b5ee664b.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.32455.src.430f5cb5.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/preprocessing.bash.6dd62e59.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/index.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/glass.png'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/tablesorter-theme.css'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/bcov.css'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/js/kcov.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/js/handlebars.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/js/jquery.min.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/js/jquery.tablesorter.widgets.min.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/js/tablesorter.min.js'
# removed directory './temp/tpc/bats.e38fe61c8733e2cd/data/js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/data/amber.png'
# removed directory './temp/tpc/bats.e38fe61c8733e2cd/data'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/coverage.json'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/index.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.51601793.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/summary.db'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats.b5ee664b.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/codecov.json'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-format-cat.c477ed39.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/cobertura.xml'
# removed './temp/tpc/bats.e38fe61c8733e2cd/tracing.bash.d47fd49d.html'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-exec-suite.55314897.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/test_functions.bash.e2c749da.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/validator.bash.d35e7a84.js'
# removed './temp/tpc/bats.e38fe61c8733e2cd/amber.png'
# removed './temp/tpc/bats.e38fe61c8733e2cd/bats-preprocess.c89b1ce6.html'
# removed directory './temp/tpc/bats.e38fe61c8733e2cd'
# removed './temp/tpc/bash-helper.sh'
# removed './temp/tpc/bcov.css'
# removed './temp/tpc/index.html'
# removed './temp/tpc/data/glass.png'
# removed './temp/tpc/data/tablesorter-theme.css'
# removed './temp/tpc/data/bcov.css'
# removed './temp/tpc/data/js/kcov.js'
# removed './temp/tpc/data/js/handlebars.js'
# removed './temp/tpc/data/js/jquery.min.js'
# removed './temp/tpc/data/js/jquery.tablesorter.widgets.min.js'
# removed './temp/tpc/data/js/tablesorter.min.js'
# removed directory './temp/tpc/data/js'
# removed './temp/tpc/data/amber.png'
# removed directory './temp/tpc/data'
# removed './temp/tpc/bats'
# removed './temp/tpc/libbash_execve_redirector.so'
# removed './temp/tpc/index.js'
# removed './temp/tpc/bash-helper-debug-trap.sh'
# removed './temp/tpc/libbash_tracefd_cloexec.so'
# removed './temp/tpc/amber.png'
# removed directory './temp/tpc'
# removed './temp/envopts.py'
# removed directory './temp'
# removed './testbook-test-dir-aliases.ipynb'
# removed './test-check-errors.ipynb'
# removed './test_check_errors.py'
# removed './test-cond-env-setting.ipynb'
# removed './test-dir-alias.ipynb'
# removed './test_extract_matches.py'
# removed './test_tomohara_aliases.bats'
# removed './test_tpo_count_it.py'
# removed './tmp/test-cp-mv/test-1210/testdir1/.bashrc'
# removed directory './tmp/test-cp-mv/test-1210/testdir1'
# removed directory './tmp/test-cp-mv/test-1210'
# removed directory './tmp/test-cp-mv'
# removed directory './tmp'
# removed './tomasohara-aliases-test.ipynb'
# removed './tom_auto_batspp_mezcla.py'
# removed './trace-extensionless-shortcut-unicode.batspp'
# removed './trace-extensionless-shortcut-unicode.ipynb'
# removed './trace-extensionless-shortcut-V2.ipynb'
# removed './trace-file-manipulation-Copy1.ipynb'
# removed './trace-file-manipulation.ipynb'
# removed './trace-line-words-commands.ipynb'
# removed './trace-linux-admin-alias.ipynb'
# removed './trace-python-commands.ipynb'
# removed './trace-setup-sorting-wrappers.ipynb'
# removed './trace-unix-alias.ipynb'
# removed './trace-unix-general.ipynb'
# removed './txt-reports/trace-extensionless-shortcut-V2.txt'
# removed './txt-reports/test-check-errors.txt'
# removed './txt-reports/command-override-cp-mv.txt'
# removed './txt-reports/hello-world-revised.txt'
# removed './txt-reports/trace-python-commands.txt'
# removed './txt-reports/alias-calculator-commands.txt'
# removed './txt-reports/trace-unix-alias.txt'
# removed './txt-reports/trace-setup-sorting-wrappers.txt'
# removed './txt-reports/testbook-test-dir-aliases.txt'
# removed './txt-reports/alias-cd-commands.txt'
# removed './txt-reports/trace-line-words-commands.txt'
# removed './txt-reports/calc-entropy-tests.txt'
# removed './txt-reports/tomasohara-aliases-test.txt'
# removed './txt-reports/dir-aliases-test-revised.txt'
# removed './txt-reports/json-related-alias.txt'
# removed './txt-reports/more-tomohara-aliases-test.txt'
# removed './txt-reports/test-dir-alias.txt'
# removed './txt-reports/trace-unix-general.txt'
# removed './txt-reports/test-cond-env-setting.txt'
# removed './txt-reports/trace-file-manipulation.txt'
# removed './txt-reports/alias-grep-commands.txt'
# removed './txt-reports/trace-linux-admin-alias.txt'
# removed './txt-reports/hello-world-basic.txt'
# removed './txt-reports/alias-trace-misc-commands.txt'
# removed './txt-reports/trace-extensionless-shortcut-unicode.txt'
# removed directory './txt-reports'
# Backing up 'freemem_mb.txt' to './backup/freemem_mb.txt'
# bash: BACKUP/freemem_mb.txt: No such file or directory
# linebr: command not found
# testnum: command not found
# testuser: command not found
# linebr: command not found
# testnum: command not found
# : 127

# %%
# T2 - FOR FILE MANIPULATION REGARDING ALIASES
alias remove-cr='tr -d "\r"'
alias perl-slurp='perl -0777'
alias alt-remove-cr='perl-slurp -pe "s/\r//g;"'
function remove-cr-and-backup () { $BIN_DIR/dobackup.sh "$1"; remove-cr < backup/"$1" >| "$1"; }
alias perl-remove-cr='perl -i.bak -pn -e "s/\r//;"'

# %%
# perl-slurp IS AN ALIAS FOR 'perl -0777'
perl-slurp -v | testnum
# Out:
# This is perl X, version XX, subversion X (vX.XX.X) built for xXX_XX-linux-gnu-thread-multi
# (with XX registered patches, see perl -V for more detail)
#
# Copyright XXXX-XXXX, Larry Wall
#
# Perl may be copied only under the terms of either the Artistic License or the
# GNU General Public License, which may be found in the Perl X source kit.
#
# Complete documentation for Perl, including FAQ lists, should be found on
# this system using "man perl" or "perldoc perl".  If you have access to the
# Internet, point your browser at http://www.perl.org/, the Perl Home Page.

# %%
# remove-cr & alt-remove-cr REMOVES \r from TEXT
function test-text () { printf "THIS IS A TEST. \rTHIS IS ALSO A TEST\r. THIS IS A TEST TOO."; }
test-text

printf "\n"
linebr

test-text | remove-cr

printf "\n"
linebr

test-text | alt-remove-cr
# Out:
# . THIS IS A TEST TOO.
# --------------------------------------------------------------------------------
# THIS IS A TEST. THIS IS ALSO A TEST. THIS IS A TEST TOO.
# --------------------------------------------------------------------------------
# THIS IS A TEST. THIS IS ALSO A TEST. THIS IS A TEST TOO.

# %%
# remove-cr-and-backup REMOVES \r AND ALSO CREATES A BACKUP IN THE BACKUP FOLDER
ps -l > process_list.txt
remove-cr-and-backup process_list.txt
# Out:
# Backing up 'process_list.txt' to './backup/process_list.txt'

# %%
# perl-remove-cr REMOVES \r USING PERL 
test-text | perl-remove-cr
# Out:
# -i used with no filenames on the command line, reading from STDIN.
# . THIS IS A TEST TOO.IS ALSO A TEST

# %%
# T3 - FOR TEXT MANIPULATION

# Text manipulation
alias intersection='$BIN_DIR/intersection.perl'
alias difference='intersection -diff'
alias line-intersection='intersection -line'
alias line-difference='intersection -diff -line'
function show-line () { tail --lines=+"$1" "$2" | head -1; }
#
# last-n-with-header(num, file): create sub-file with last NUM lines plus header from FILE
function last-n-with-header () { head --lines=1 "$2"; tail --lines="$1" "$2"; }

# %%
# TESTING INTERSECTION FOR ps
ps -u > ntest1.txt
ps -l > ntest2.txt
intersection ntest1.txt ntest2.txt | testnum
# Out:
# PID
# TTY
# TIME
# bash
# XXXX
# pts/X
# pts/X
# ps

# %%
# difference = intersection -diff
difference ntest1.txt ntest2.txt | testuser | testnum
# Out:
# %CPU
# %MEM
# --rcfile
# -u
# /home/user/.local/bin/jupyter-notebook
# /usr/bin/bash
# /usr/bin/pythonX
# /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# X.X
# X.X
# X:XX
# X:XX
# X.X
# X.X
# XXXXX
# XXXXX
# XXXXX
# XX:XX
# XX:XX
# XXXXX
# XX:XX
# XX:XX
# XX:XX
# XX:XX
# XX:XX
# XX:XX
# XX:XX
# XX:XX
# XX:XX
# XX:XX
# X.X
# XXXX
# XXXX
# XXXX
# XXXXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXXX
# COMMAND
# R+
# RSS
# START
# STAT
# Sl+
# Ss
# Ss+
# USER
# VSZ
# user
# pts/X
# pts/X
# pts/X
# pts/X
# pts/X
# pts/X
# pts/X
# pts/X
# pts/X

# %%
# line-intersection = intersection -line
free -m > free1.txt
free > free2.txt
line-intersection free1.txt free2.txt
# Out:
#                total        used        free      shared  buff/cache   available

# %%
# line-difference = intersecton -diff -line
line-difference free1.txt free2.txt | testnum
linebr
line-difference free2.txt free1.txt | testnum
# Out:
# Mem:            XXXX        XXXX         XXX         XXX        XXXX         XXX
# Swap:           XXXX         XXX        XXXX
# --------------------------------------------------------------------------------
# Mem:         XXXXXXX     XXXXXXX      XXXXXX      XXXXXX     XXXXXXX      XXXXXX
# Swap:        XXXXXXX      XXXXXX     XXXXXXX

# %%
# show-line SHOWS n LINE FROM A FILE 
# (SYNTAX: show-line [LINE-NUMBER] [SOURCE-FILE])
cat ntest1.txt | testuser | testnum
linebr
show-line 3 ntest1.txt | testuser | testnum
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss   XX:XX   X:XX bash
# user       XXXX  X.X  X.X XXXXXX XXXXX pts/X    Sl+  XX:XX   X:XX /usr/bin/pythonX /home/user/.local/bin/jupyter-notebook
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss   XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    R+   XX:XX   X:XX ps -u
# --------------------------------------------------------------------------------
# user       XXXX  X.X  X.X XXXXXX XXXXX pts/X    Sl+  XX:XX   X:XX /usr/bin/pythonX /home/user/.local/bin/jupyter-notebook

# %%
# last-n-with-header GIVES LAST n LINES + HEADING LINE
last-n-with-header 4 ntest1.txt | testuser | testnum
linebr
last-n-with-header 2 ntest2.txt | testuser | testnum
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss+  XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    Ss   XX:XX   X:XX /usr/bin/bash --rcfile /usr/lib/pythonX/dist-packages/pexpect/bashrc.sh
# user       XXXX  X.X  X.X  XXXXX  XXXX pts/X    R+   XX:XX   X:XX ps -u
# --------------------------------------------------------------------------------
# F S   UID     PID    PPID  C PRI  NI ADDR SZ WCHAN  TTY          TIME CMD
# X S  XXXX    XXXX    XXXX  X  XX   X -  XXXX do_wai pts/X    XX:XX:XX bash
# X R  XXXX    XXXX    XXXX  X  XX   X -  XXXX -      pts/X    XX:XX:XX ps

# %%
# CLEARS THE TEST FOLDER
rm -rf ./*
