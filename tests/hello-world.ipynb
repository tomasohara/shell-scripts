# %%
# The hello world of Bats-pp tests

# %%
## OLD: echo 'Hello world' | wc -l

# %%
echo 'Hello world' | grep -ic hello.world
# Out:
# 1

# %%
## Wrapup
echo "Seconds since epoch: $(date +%s.%3N)"
# Out:
# Seconds since epoch: 1785727322.515
